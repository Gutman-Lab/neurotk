# %% [markdown]
# # Testing snippets

# %%
import large_image
import matplotlib.pyplot as plt

# %%
ts = large_image.getTileSource("/home/jvizcar/data/E20-106_1 AB.svs")

kwargs = {
    "scale": {"magnification": 2.0}, "format": large_image.tilesource.TILE_FORMAT_NUMPY
}

thumbnail_img = ts.getRegion(**kwargs)[0][:, :, :3]

plt.imshow(thumbnail_img)
plt.show()

# %%
ts.getMetadata()
# Out:
# {'levels': 10,
#  'sizeX': 113543,
#  'sizeY': 84212,
#  'tileWidth': 240,
#  'tileHeight': 240,
#  'magnification': 40.0,
#  'mm_x': 0.0002519,
#  'mm_y': 0.0002519,
#  'dtype': 'uint8',
#  'bandCount': 4}

# %%
thumbnail_img[1]
# Out:
# 'numpy'
